# %%
from tensorflow.keras.preprocessing import image
import  cv2
import matplotlib.pyplot as plt
i = cv2.imread('./SYS809_projet2021_sequences1/livre1.JPG' )    
resized_image = cv2.resize(i, (224, 224)) 

##
#plt.gca().invert_yaxis()
plt.figure()
plt.imshow(i)
plt.show()
